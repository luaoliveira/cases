# %%
import pandas as pd 
import geopandas as gpd
import matplotlib.pyplot as plt
import country_converter as coco
from geopandas import GeoDataFrame

# %%
uri="https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv"
SHAPEFILE="UIA_Latitude_Longitude_Graticules_and_World_Countries_Boundaries.shp"

# %%
dfd = pd.read_csv(uri)

# %%
dfd.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
geo_df = gpd.read_file(SHAPEFILE)

# %%
geo_df
# Out:
#      OBJECTID           CNTRY_NAME  \
# 0           1                Aruba
# 1           2  Antigua and Barbuda
# 2           3          Afghanistan
# 3           4              Algeria
# 4           5           Azerbaijan
# ..        ...                  ...
# 246       247        Western Samoa
# 247       248            Swaziland
# 248       249                Yemen
# 249       250               Zambia
# 250       251             Zimbabwe
#
#                                               geometry
# 0    POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1    MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2    POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3    POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4    MULTIPOLYGON (((45.02583 41.03055, 45.00999 41...
# ..                                                 ...
# 246  MULTIPOLYGON (((-172.59650 -13.50911, -172.551...
# 247  POLYGON ((30.89944 -26.77195, 30.88028 -26.793...
# ...

# %%
geo_df = geo_df.drop(geo_df.loc[geo_df['CNTRY_NAME']=='Antarctica'].index)

# %%
geo_df
# Out:
#      OBJECTID           CNTRY_NAME  \
# 0           1                Aruba
# 1           2  Antigua and Barbuda
# 2           3          Afghanistan
# 3           4              Algeria
# 4           5           Azerbaijan
# ..        ...                  ...
# 246       247        Western Samoa
# 247       248            Swaziland
# 248       249                Yemen
# 249       250               Zambia
# 250       251             Zimbabwe
#
#                                               geometry
# 0    POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1    MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2    POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3    POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4    MULTIPOLYGON (((45.02583 41.03055, 45.00999 41...
# ..                                                 ...
# 246  MULTIPOLYGON (((-172.59650 -13.50911, -172.551...
# 247  POLYGON ((30.89944 -26.77195, 30.88028 -26.793...
# ...

# %%
dfd[dfd['country'].str.startswith('U')]
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 179                Uganda             45                9              0
# 180               Ukraine            206              237             45
# 181  United Arab Emirates             16              135              5
# 182        United Kingdom            219              126            195
# 184                   USA            249              158             84
# 185               Uruguay            115               35            220
# 186            Uzbekistan             25              101              8
#
#      total_litres_of_pure_alcohol
# 179                           8.3
# 180                           8.9
# 181                           2.8
# 182                          10.4
# 184                           8.7
# 185                           6.6
# 186                           2.4

# %%
geo_df[geo_df['CNTRY_NAME'].str.startswith('U')]
# Out:
#      OBJECTID            CNTRY_NAME  \
# 214       215  United Arab Emirates
# 229       230                Uganda
# 230       231        United Kingdom
# 231       232               Ukraine
# 232       233         United States
# 234       235               Uruguay
# 235       236            Uzbekistan
#
#                                               geometry
# 214  MULTIPOLYGON (((56.28047 24.85727, 56.26944 24...
# 229  POLYGON ((32.89035 -0.99971, 32.74242 -0.99972...
# 230  MULTIPOLYGON (((-0.83500 60.67333, -0.93556 60...
# 231  POLYGON ((31.85253 46.52267, 31.89638 46.51859...
# 232  MULTIPOLYGON (((-134.97501 58.64583, -134.9213...
# 234  POLYGON ((-58.38889 -33.42250, -58.41590 -33.4...
# 235  POLYGON ((68.64267 39.85824, 68.63721 39.83943...

# %%
dfd.loc[dfd.country == 'USA'] = 'United States'

# %%
geo_df.plot(figsize=(20,20), edgecolor='white', linewidth=1, color='lightgreen')
# Out:
# <AxesSubplot:>

# %%
df = dfd.merge(geo_df, how='inner', left_on='country', right_on='CNTRY_NAME')

# %%
df.head()
# Out:
#        country beer_servings spirit_servings wine_servings  \
# 0  Afghanistan             0               0             0
# 1      Albania            89             132            54
# 2      Algeria            25               0            14
# 3      Andorra           245             138           312
# 4       Angola           217              57            45
#
#   total_litres_of_pure_alcohol  OBJECTID   CNTRY_NAME  \
# 0                          0.0         3  Afghanistan
# 1                          4.9         6      Albania
# 2                          0.7         4      Algeria
# 3                         12.4         8      Andorra
# 4                          5.9         9       Angola
#
#                                             geometry
# 0  POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 1  POLYGON ((20.79192 40.43154, 20.78722 40.39472...
# 2  POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 3  POLYGON ((1.44583 42.60194, 1.48653 42.65041, ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
d
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
#       ...
# 169    333
# 170    111
# 171      6
# 172     32
# 173     64
# Name: beer_servings, Length: 174, dtype: object

# %%
vmin = df['beer_servings'].astype(int).min()
vmax=df['beer_servings'].astype(int).max()
cmap = 'cool'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8821/158836038.py in <module>
# ----> 1 vmin = df['beer_servings'].astype(int).min()
#       2 vmax=df['beer_servings'].astype(int).max()
#       3 cmap = 'cool'
#
# ~/penv/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/penv/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
fig, ax = plt.subplots(1, figsize=(20,8))
ax.axis('off')
df.plot(column='beer_servings', ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap)
ax.set_title('Beer Servings per country', fontdict={'fontsize':'25', 'fontweight': '3'})
sm = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)
sm._A=[]
cbaxes=fig.add_axes([0.15, 0.25, 0.01, 0.4])
cbar = fig.colorbar(sm, cax=cbaxes)

# %%
vmin = df['wine_servings'].min()
vmax=df['wine_servings'].max()

# %%
fig, ax = plt.subplots(1, figsize=(20,8))
df.plot(column='wine_servings', ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap)
sm = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)
